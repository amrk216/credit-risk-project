# %%
import pandas as pd  # pyright: ignore[reportMissingModuleSource]
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('.\data\data_clean.csv')

# %%
df.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          21           9600                   OWN                5.0
# 1          25           9600              MORTGAGE                1.0
# 2          23          65500                  RENT                4.0
# 3          24          54400                  RENT                8.0
# 4          21           9900                   OWN                2.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0   EDUCATION          B       1000          11.14            0
# 1     MEDICAL          C       5500          12.87            1
# 2     MEDICAL          C      35000          15.23            1
# 3     MEDICAL          C      35000          14.27            1
# 4     VENTURE          A       2500           7.14            1
#
#    loan_percent_income  cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.10                          0                           2
# ...

# %%
sns.lineplot(df,x='loan_intent',y='loan_int_rate',hue='loan_status')

plt.xticks(rotation=45)
plt.grid()

# %%
sns.countplot(df,x="loan_status",palette="Set1")
plt.grid()
# Out:
# C:\Users\Amr Khaled\AppData\Local\Temp\ipykernel_4496\918055770.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df,x="loan_status",palette="Set1")

# %%
sns.countplot(df,x="person_home_ownership",hue="loan_status",palette="Set1")
plt.grid()

# %%
sns.countplot(df,x="loan_intent",hue="loan_status",palette="Set1")
plt.xticks(rotation=45)

plt.grid()

# %%
sns.countplot(df,x="loan_grade",hue="loan_status",palette="Set1")
plt.xticks(rotation=45)

plt.grid()

# %%
df['loan_percent_income'].hist(bins=30)
plt.title("Loan Percent Income Distribution")
# Out:
# Text(0.5, 1.0, 'Loan Percent Income Distribution')

# %%
df['loan_int_rate'].hist(bins=30)
# Out:
# <Axes: >

# %%
df['person_emp_length'].hist(bins=30)
plt.title("Person Employment Length Distribution")
# Out:
# Text(0.5, 1.0, 'Person Employment Length Distribution')

# %%
plt.figure(figsize=(10,6))
sns.lineplot(df,x="loan_amnt",y="loan_int_rate",hue="loan_status",palette="Set1")
plt.grid()

# %%
sns.boxplot(df,x='loan_status',y='loan_percent_income',palette='cool')
# Out:
# C:\Users\Amr Khaled\AppData\Local\Temp\ipykernel_4496\2530890867.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(df,x='loan_status',y='loan_percent_income',palette='cool')
# <Axes: xlabel='loan_status', ylabel='loan_percent_income'>

# %%
df[df['loan_percent_income']>0.70]
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 456            24          18000                   OWN                6.0
# 567            21          19500              MORTGAGE                0.0
# 572            26          26000                  RENT               10.0
# 635            22          20000              MORTGAGE                0.0
# 2446           25          32004              MORTGAGE                3.0
# 10001          21          13000                  RENT                0.0
# 18197          30          32004                  RENT                1.0
# 23721          32          12000                  RENT                1.0
# 27872          33          10080                   OWN               11.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 456             PERSONAL          A      13000           7.88            1
# 567            EDUCATION          B      15000           9.64            1
# ...

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.select_dtypes(include='number').corr(), annot=True, fmt=".2f", cmap="coolwarm")
plt.show()

# %%
sns.barplot(df,x="cb_person_default_on_file",y = "loan_percent_income",hue='loan_status')
# Out:
# <Axes: xlabel='cb_person_default_on_file', ylabel='loan_percent_income'>
